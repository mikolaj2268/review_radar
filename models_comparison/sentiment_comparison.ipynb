# %%
import pandas as pd

file_path = 'models_comparison/reviews_with_sentiments.parquet'
df = pd.read_parquet(file_path)

df.head()
# Out:
#                               review_id          at  \
# 0  4423e3f0-6002-469c-bf91-239a1ba1d998  2024-11-23
# 1  16d24c6a-d3ea-4558-9a6b-2694beb581ec  2024-11-23
# 2  14098fe6-6649-4fb4-aeb1-f1b36fdcca6f  2024-11-23
# 3  6b215132-0eaf-40f7-a7f4-758c8fbf35b1  2024-11-23
# 4  b57b2878-92ba-4468-a3dc-722f2c61b51b  2024-11-23
#
#                                              content  score app_name  \
# 0                                      No comment 😭😔      5  Netflix
# 1  lately the sounds go thru but no picture...its...      2  Netflix
# 2                                 This is very good👍      5  Netflix
# 3  Why auto payment with bank is activated after ...      1  Netflix
# 4  Keeps updating every 2 days and suddenly canno...      1  Netflix
#
#    textblob_pattern_polarity  textblob_pattern_subjectivity  vader_neg  \
# 0                       0.00                           0.00      0.500
# 1                      -0.55                           0.75      0.205
# 2                       0.20                           0.30      0.000
# 3                       0.00                           0.00      0.000
# 4                       0.00                           0.50      0.000
#
#    vader_neu  vader_pos  vader_compound  distilbert_negative_prob  \
# 0      0.377      0.123         -0.6124                  0.987631
# 1      0.584      0.211          0.0225                  0.999301
# 2      0.610      0.390          0.4927                  0.034944
# 3      1.000      0.000          0.0000                  0.996918
# 4      1.000      0.000          0.0000                  0.999739
#
#    distilbert_positive_prob  distilbert_sentiment_score  \
# 0                  0.012369                   -0.975263
# 1                  0.000699                   -0.998603
# 2                  0.965056                    0.930112
# 3                  0.003082                   -0.993837
# 4                  0.000261                   -0.999478
#
#   distilbert_sentiment_label  roberta_negative_prob  roberta_neutral_prob  \
# 0                   NEGATIVE               0.817729              0.172929
# 1                   NEGATIVE               0.913306              0.082218
# 2                   POSITIVE               0.004413              0.011624
# 3                   NEGATIVE               0.207172              0.769924
# 4                   NEGATIVE               0.779235              0.208691
#
#    roberta_positive_prob roberta_sentiment_label
# 0               0.009343                NEGATIVE
# 1               0.004477                NEGATIVE
# 2               0.983962                POSITIVE
# 3               0.022904                 NEUTRAL
# 4               0.012074                NEGATIVE

# %%
df
# Out:
#                                    review_id          at  \
# 0       4423e3f0-6002-469c-bf91-239a1ba1d998  2024-11-23
# 1       16d24c6a-d3ea-4558-9a6b-2694beb581ec  2024-11-23
# 2       14098fe6-6649-4fb4-aeb1-f1b36fdcca6f  2024-11-23
# 3       6b215132-0eaf-40f7-a7f4-758c8fbf35b1  2024-11-23
# 4       b57b2878-92ba-4468-a3dc-722f2c61b51b  2024-11-23
# ...                                      ...         ...
# 698683  be7dbfec-64b5-4fba-b2be-e63e6d38451c  2024-01-01
# 698684  2a3d5968-2d11-4d45-8acc-60a5afb3542b  2024-01-01
# 698685  1b4c66f6-47e1-46e7-8f04-5d5147f5971a  2024-01-01
# 698686  ef3d7343-35bb-4867-9a58-fa1415a71536  2024-01-01
# 698687  608d8eaf-79e5-4fb9-a48f-30b5efcbe67e  2024-01-01
#
#                                                   content  score app_name  \
# 0                                           No comment 😭😔      5  Netflix
# 1       lately the sounds go thru but no picture...its...      2  Netflix
# 2                                      This is very good👍      5  Netflix
# 3       Why auto payment with bank is activated after ...      1  Netflix
# 4       Keeps updating every 2 days and suddenly canno...      1  Netflix
# ...                                                   ...    ...      ...
# 698683  This app is terrible the people are gross and ...      1        X
# 698684                                               Good      5        X
# 698685  Best thing to slice bread. Like Whattsup call ...      5        X
# 698686                                     No issues here      5        X
# 698687                                          Fantastic      5        X
#
#         textblob_pattern_polarity  textblob_pattern_subjectivity  vader_neg  \
# 0                        0.000000                       0.000000      0.500
# 1                       -0.550000                       0.750000      0.205
# 2                        0.200000                       0.300000      0.000
# 3                        0.000000                       0.000000      0.000
# 4                        0.000000                       0.500000      0.000
# ...                           ...                            ...        ...
# 698683                  -0.383333                       0.466667      0.533
# 698684                   0.700000                       0.600000      0.000
# 698685                   1.000000                       0.300000      0.000
# 698686                   0.000000                       0.000000      0.524
# 698687                   0.400000                       0.900000      0.000
#
#         vader_neu  vader_pos  vader_compound  distilbert_negative_prob  \
# 0           0.377      0.123         -0.6124                  0.987631
# 1           0.584      0.211          0.0225                  0.999301
# 2           0.610      0.390          0.4927                  0.034944
# 3           1.000      0.000          0.0000                  0.996918
# 4           1.000      0.000          0.0000                  0.999739
# ...           ...        ...             ...                       ...
# 698683      0.467      0.000         -0.9713                  0.999678
# 698684      0.000      1.000          0.4404                  0.000184
# 698685      0.717      0.283          0.7717                  0.996566
# 698686      0.476      0.000         -0.2960                  0.007601
# 698687      0.000      1.000          0.5574                  0.000126
#
#         distilbert_positive_prob  distilbert_sentiment_score  \
# 0                       0.012369                   -0.975263
# 1                       0.000699                   -0.998603
# 2                       0.965056                    0.930112
# 3                       0.003082                   -0.993837
# 4                       0.000261                   -0.999478
# ...                          ...                         ...
# 698683                  0.000322                   -0.999355
# 698684                  0.999816                    0.999632
# 698685                  0.003435                   -0.993131
# 698686                  0.992399                    0.984797
# 698687                  0.999874                    0.999749
#
#        distilbert_sentiment_label  roberta_negative_prob  \
# 0                        NEGATIVE               0.817729
# 1                        NEGATIVE               0.913306
# 2                        POSITIVE               0.004413
# 3                        NEGATIVE               0.207172
# 4                        NEGATIVE               0.779235
# ...                           ...                    ...
# 698683                   NEGATIVE               0.960286
# 698684                   POSITIVE               0.052735
# 698685                   NEGATIVE               0.012394
# 698686                   POSITIVE               0.080536
# 698687                   POSITIVE               0.011723
#
#         roberta_neutral_prob  roberta_positive_prob roberta_sentiment_label
# 0                   0.172929               0.009343                NEGATIVE
# 1                   0.082218               0.004477                NEGATIVE
# 2                   0.011624               0.983962                POSITIVE
# 3                   0.769924               0.022904                 NEUTRAL
# 4                   0.208691               0.012074                NEGATIVE
# ...                      ...                    ...                     ...
# 698683              0.034162               0.005552                NEGATIVE
# 698684              0.262828               0.684437                POSITIVE
# 698685              0.093221               0.894385                POSITIVE
# 698686              0.622753               0.296711                 NEUTRAL
# 698687              0.050794               0.937483                POSITIVE
#
# [698688 rows x 19 columns]

# %%
unique_app_names = df['app_name'].unique()
print(unique_app_names)
# Out:
# ['Netflix' 'Messenger' 'Google Maps' 'X']

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(df['distilbert_sentiment_label'], bins=50, edgecolor='k')
plt.title('Distribution of DistilBERT Sentiment Score')
plt.xlabel('DistilBERT Sentiment Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Correlation

# %%
correlation_features = [
    'textblob_pattern_polarity',
    'vader_neg', 'vader_neu', 'vader_pos', 'vader_compound',
    'distilbert_negative_prob', 'distilbert_positive_prob',
    'roberta_negative_prob', 'roberta_neutral_prob', 'roberta_positive_prob',
    'score'
]

correlation_matrix = df[correlation_features].corr()

correlation_with_score = correlation_matrix['score'].drop('score')

print("Correlations of the `score` variable with features:")
print(correlation_with_score)
# Out:
# Korelacje zmiennej `score` z cechami:
# textblob_pattern_polarity    0.554933
# vader_neg                   -0.394413
# vader_neu                   -0.414962
# vader_pos                    0.549060
# vader_compound               0.579651
# distilbert_negative_prob    -0.668023
# distilbert_positive_prob     0.668023
# roberta_negative_prob       -0.719535
# roberta_neutral_prob        -0.058936
# roberta_positive_prob        0.692403
# Name: score, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

def group_correlation(X, y):
    model = LinearRegression()
    model.fit(X, y)
    y_pred = model.predict(X)
    r2 = r2_score(y, y_pred)
    return r2

features_groups = {
    'TextBlob': ['textblob_pattern_polarity'],
    'VADER': ['vader_neg', 'vader_neu', 'vader_pos', 'vader_compound'],
    'DistilBERT': ['distilbert_negative_prob', 'distilbert_positive_prob'],
    'RoBERTa': ['roberta_negative_prob', 'roberta_neutral_prob', 'roberta_positive_prob']
}

group_correlations = {}
for group_name, features in features_groups.items():
    r2 = group_correlation(df[features], df['score'])
    group_correlations[group_name] = r2

print("Group correlations (`score` from group variables) as R-squared:")
for group, r2 in group_correlations.items():
    print(f"{group}: {r2:.2f}")
# Out:
# Korelacje grupowe (`score` od zmiennych grupy) jako R-squared:
# TextBlob: 0.31
# VADER: 0.39
# DistilBERT: 0.45
# RoBERTa: 0.56
